# %% [markdown]
# # Задвання
#
# Руцями взяти похідну сігмоїдної функції
#
# Проексперементувати з градієнтним спуском
#
# Зробити форвард і беквард до функції L = (2a + b)(c - d)

# %% [markdown]
# # Перше завдання
# **уявімо, що фотки з телефона тут**

# %% [markdown]
# **Дано код**

# %%
from typing import List, Tuple
import numpy as np
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt


np.random.seed(1337)


def get_data(nsamples: int = 100) -> Tuple[np.array, np.array]:
    x = np.linspace(0, 10, nsamples)
    y = 2 * x + 3.5
    return (x, y)


def add_noise(y: np.array) -> np.array:
    noise = np.random.normal(size=y.size)
    return y + noise


def gradient_descent(X: np.array, y: np.array, 
                     lr: float = 0.01, 
                     epoch: int = 1000) -> Tuple[
                                            float, 
                                            float, 
                                            List[Tuple[float, float]],
                                            List[float]]:
    """
    Gradient Descent for a single feature
    """

    m, b = 0.33, 0.48  # initial guess for parameters
    log, mse = [], []  # lists to store learning process
    N = len(X)         # number of samples
    
    for _ in range(epoch):
                
        f = y - (m*X + b)
    
        # Updating m and b
        m -= lr * (-2 * X.dot(f).sum() / N)
        b -= lr * (-2 * f.sum() / N)
        
        log.append((m, b))
        mse.append(mean_squared_error(y, (m*X + b)))        
    
    return m, b, log, mse


if __name__ == "__main__":
    # Getting data
    x, y_true = get_data()
    y = add_noise(y_true)

    # Plot and investigate data
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.plot(x, y, "o", label="data")
    ax.legend(loc="best")
    plt.savefig("data.png")

    m, b, log, mse = gradient_descent(x, y)
    print(f"Params:\n\t{m = }\n\t{b = }")

    # Plot results
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.plot(x, y, "o", label="data")
    ax.plot(x, y_true, "b-", label="True")
    ax.plot(x, m*x+b, "r--.", label="Gradient Descent")
    ax.legend(loc="best")

    plt.savefig("gd_regression.png")
# Out:
# Params:
# 	m = 2.003222509810484
# 	b = 3.3248920388471914

# %% [markdown]
# # Задача два
#
# 10 epochs

# %%
def get_data(nsamples: int = 100) -> Tuple[np.array, np.array]:
    x = np.linspace(0, 10, nsamples)
    y = 2 * x + 3.5
    return (x, y)


def add_noise(y: np.array) -> np.array:
    noise = np.random.normal(size=y.size)
    return y + noise


def gradient_descent(X: np.array, y: np.array, 
                     lr: float = 0.01, 
                     epoch: int = 10) -> Tuple[
                                            float, 
                                            float, 
                                            List[Tuple[float, float]],
                                            List[float]]:
    """
    Gradient Descent for a single feature
    """

    m, b = 0.33, 0.48  # initial guess for parameters
    log, mse = [], []  # lists to store learning process
    N = len(X)         # number of samples
    
    for _ in range(epoch):
                
        f = y - (m*X + b)
    
        # Updating m and b
        m -= lr * (-2 * X.dot(f).sum() / N)
        b -= lr * (-2 * f.sum() / N)
        
        log.append((m, b))
        mse.append(mean_squared_error(y, (m*X + b)))        
    
    return m, b, log, mse


if __name__ == "__main__":
    # Getting data
    x, y_true = get_data()
    y = add_noise(y_true)

    # Plot and investigate data
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.plot(x, y, "o", label="data")
    ax.legend(loc="best")
    plt.savefig("data.png")

    m, b, log, mse = gradient_descent(x, y)
    print(f"Params:\n\t{m = }\n\t{b = }")

    # Plot results
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.plot(x, y, "o", label="data")
    ax.plot(x, y_true, "b-", label="True")
    ax.plot(x, m*x+b, "r--.", label="Gradient Descent")
    ax.legend(loc="best")

    fig, ax = plt.subplots(figsize=(8, 6))
    ax.plot(mse, [i for i in range(1, len(mse)+1)])
    plt.savefig("10epochs.png")
# Out:
# Params:
# 	m = 2.3883177298208396
# 	b = 0.9260114091850652

# %% [markdown]
# **Як можемо бачити з графіків, 10 епох недостатньо, щоб функція встигла знайти мінімум. Але знаходиться в зоні наших даних.**
#
# # Завдання два
# **LR = 1**

# %%
def get_data(nsamples: int = 100) -> Tuple[np.array, np.array]:
    x = np.linspace(0, 10, nsamples)
    y = 2 * x + 3.5
    return (x, y)


def add_noise(y: np.array) -> np.array:
    noise = np.random.normal(size=y.size)
    return y + noise


def gradient_descent(X: np.array, y: np.array, 
                     lr: float = 1, 
                     epoch: int = 10) -> Tuple[
                                            float, 
                                            float, 
                                            List[Tuple[float, float]],
                                            List[float]]:
    """
    Gradient Descent for a single feature
    """

    m, b = 0.33, 0.48  # initial guess for parameters
    log, mse = [], []  # lists to store learning process
    N = len(X)         # number of samples
    
    for _ in range(epoch):
                
        f = y - (m*X + b)
    
        # Updating m and b
        m -= lr * (-2 * X.dot(f).sum() / N)
        b -= lr * (-2 * f.sum() / N)
        
        log.append((m, b))
        mse.append(mean_squared_error(y, (m*X + b)))        
    
    return m, b, log, mse


if __name__ == "__main__":
    # Getting data
    x, y_true = get_data()
    y = add_noise(y_true)

    # Plot and investigate data
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.plot(x, y, "o", label="data")
    ax.legend(loc="best")
    plt.savefig("data.png")

    m, b, log, mse = gradient_descent(x, y)
    print(f"Params:\n\t{m = }\n\t{b = }")

    # Plot results
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.plot(x, y, "o", label="data")
    ax.plot(x, y_true, "b-", label="True")
    ax.plot(x, m*x+b, "r--.", label="Gradient Descent")
    ax.legend(loc="best")

    fig, ax = plt.subplots(figsize=(8, 6))
    ax.plot(mse, [i for i in range(1, len(mse)+1)])
    plt.savefig("high_lr.png")
# Out:
# Params:
# 	m = -4.065730923083624e+18
# 	b = -6.113240453509905e+17

# %% [markdown]
# **Маючи завеликий learning rate взагалі заважає функції знайти мінімум.**
#
# # Завдання два
#
# **LR = 0.001; Epoch = 1000**

# %%
def get_data(nsamples: int = 100) -> Tuple[np.array, np.array]:
    x = np.linspace(0, 10, nsamples)
    y = 2 * x + 3.5
    return (x, y)


def add_noise(y: np.array) -> np.array:
    noise = np.random.normal(size=y.size)
    return y + noise


def gradient_descent(X: np.array, y: np.array, 
                     lr: float = 0.001, 
                     epoch: int = 1000) -> Tuple[
                                            float, 
                                            float, 
                                            List[Tuple[float, float]],
                                            List[float]]:
    """
    Gradient Descent for a single feature
    """

    m, b = 0.33, 0.48  # initial guess for parameters
    log, mse = [], []  # lists to store learning process
    N = len(X)         # number of samples
    
    for _ in range(epoch):
                
        f = y - (m*X + b)
    
        # Updating m and b
        m -= lr * (-2 * X.dot(f).sum() / N)
        b -= lr * (-2 * f.sum() / N)
        
        log.append((m, b))
        mse.append(mean_squared_error(y, (m*X + b)))        
    
    return m, b, log, mse


if __name__ == "__main__":
    # Getting data
    x, y_true = get_data()
    y = add_noise(y_true)

    # Plot and investigate data
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.plot(x, y, "o", label="data")
    ax.legend(loc="best")
    plt.savefig("data.png")

    m, b, log, mse = gradient_descent(x, y)
    print(f"Params:\n\t{m = }\n\t{b = }")

    # Plot results
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.plot(x, y, "o", label="data")
    ax.plot(x, y_true, "b-", label="True")
    ax.plot(x, m*x+b, "r--.", label="Gradient Descent")
    ax.legend(loc="best")

    fig, ax = plt.subplots(figsize=(8, 6))
    ax.plot(mse, [i for i in range(1, len(mse)+1)])
    plt.savefig("10x_rates.png")
# Out:
# Params:
# 	m = 2.2524925006672394
# 	b = 1.809987076208436

# %% [markdown]
# **Маючи learning rate  в 10 разів менший, так кількість epoch в 10 разів більше, все ще не достатньо для знаходження мінімума.**
#
# # Завдання два
#
# **LR = 0.01; Epoch = 10000**

# %%
def get_data(nsamples: int = 100) -> Tuple[np.array, np.array]:
    x = np.linspace(0, 10, nsamples)
    y = 2 * x + 3.5
    return (x, y)


def add_noise(y: np.array) -> np.array:
    noise = np.random.normal(size=y.size)
    return y + noise


def gradient_descent(X: np.array, y: np.array, 
                     lr: float = 0.01, 
                     epoch: int = 10000) -> Tuple[
                                            float, 
                                            float, 
                                            List[Tuple[float, float]],
                                            List[float]]:
    """
    Gradient Descent for a single feature
    """

    m, b = 0.33, 0.48  # initial guess for parameters
    log, mse = [], []  # lists to store learning process
    N = len(X)         # number of samples
    
    for _ in range(epoch):
                
        f = y - (m*X + b)
    
        # Updating m and b
        m -= lr * (-2 * X.dot(f).sum() / N)
        b -= lr * (-2 * f.sum() / N)
        
        log.append((m, b))
        mse.append(mean_squared_error(y, (m*X + b)))        
    
    return m, b, log, mse


if __name__ == "__main__":
    # Getting data
    x, y_true = get_data()
    y = add_noise(y_true)

    # Plot and investigate data
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.plot(x, y, "o", label="data")
    ax.legend(loc="best")
    plt.savefig("data.png")

    m, b, log, mse = gradient_descent(x, y)
    print(f"Params:\n\t{m = }\n\t{b = }")

    # Plot results
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.plot(x, y, "o", label="data")
    ax.plot(x, y_true, "b-", label="True")
    ax.plot(x, m*x+b, "r--.", label="Gradient Descent")
    ax.legend(loc="best")

    fig, ax = plt.subplots(figsize=(8, 6))
    ax.plot(mse, [i for i in range(1, len(mse)+1)])
    plt.savefig("high_epoch.png")
# Out:
# Params:
# 	m = 2.0116865760499496
# 	b = 3.5082639874685047

# %% [markdown]
# Завелика кількість epoch також не має сенсу, адже модель перетриновується на одному місці.
#
# # Результати
#
# Можемо зробити висновок, що правильний підбір learning rate та кільксість epoch дуже сильно впливають на роботу моделі.
#
# Настільки, що модель може взагалі не спрацювати, якщо погано підібрати параметри.
